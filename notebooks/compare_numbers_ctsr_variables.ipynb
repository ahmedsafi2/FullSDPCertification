# %%
import pandas as pd

# %%
tab1 = pd.read_csv("/share/homes/boyerma/FastSDPCertification/results/benchmark/9x200-0.015/2026_05_22_19h18_06s_SDPu-FP-stats-contraintes/part_0_50/taille_modele.csv")
tab2 = pd.read_csv("/share/homes/boyerma/FastSDPCertification/results/benchmark/9x200-0.015/2026_05_22_19h18_06s_SDPu-FP-stats-contraintes/part_50_100/taille_modele.csv")
tab = pd.concat([tab1, tab2], ignore_index=True)

# %%
STUDIES_LIST = ['Nb_constraints_total', 'Nb_variables',
       'Nb_constraints_baseline', 'Nb_constraints_RLT', 
       'Nb_constraints_triangularization', 
       'Nb_constraints_McCormick_beta_z', 
       'Nb_constraints_beta_logits_comparaison', 
       'Nb_constraints_beta_logits_comparaison_big_M',
       'Nb_constraints_sum_beta_logits_equal_logit',
       'RLT_prop']

# %%
display(tab.mean().to_frame().T[STUDIES_LIST].round())
# Out:
#    Nb_constraints_total  Nb_variables  Nb_constraints_baseline  \
# 0              104181.0      856714.0                   4327.0
#
#    Nb_constraints_RLT  Nb_constraints_triangularization  \
# 0             96756.0                             489.0
#
#    Nb_constraints_McCormick_beta_z  Nb_constraints_beta_logits_comparaison  \
# 0                           2267.0                                   144.0
#
#    Nb_constraints_beta_logits_comparaison_big_M  \
# 0                                          72.0
#
#    Nb_constraints_sum_beta_logits_equal_logit  RLT_prop
# 0                                       126.0       1.0

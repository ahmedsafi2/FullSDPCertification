# %% [markdown]
# # Tableau détaillé par point de données — `blob_nn_4x10-1` (gain vs baseline)
#
# Ce notebook fusionne tous les `results.csv` (un par combo de bound strategy) et produit
# **une ligne par point de données** (`data_index`, `target`) pour chaque combo — plus
# d'agrégation/moyenne, chaque run individuel est conservé.
#
# Colonnes produites :
# `combo, strategy, l, u_idx, k, j_idx, data_index, target, certified, optimal_value, gain, LB_neuron1, UB_neuron1, LB_neuron2, UB_neuron2`
#
# **Règles retenues** :
# - `certified` = `optimal_value > 0` (par ligne).
# - `results.csv` et `stable_actives_study.csv` sont tronqués à **78 lignes max** ; un
#   combo avec **moins de 78 lignes** est **écarté**.
# - **`gain`** = `optimal_value_combo − optimal_value_baseline` pour **ce point de
#   données précis**, en appariant chaque ligne du combo à la ligne du **baseline
#   `combo_0000`** ayant le **même `data_index` et le même `target`**.
#   → **Hypothèse à confirmer** : `(data_index, target)` identifie une ligne de façon
#   unique dans `results.csv`. Si ce n'est pas le cas, dites-le-moi et j'ajoute
#   `epsilon` à la clé de jointure.
# - **`LB_neuron1`/`UB_neuron1`/`LB_neuron2`/`UB_neuron2`** proviennent de
#   `stable_actives_study.csv`, appariées par **`data_index`** uniquement (les bornes
#   ne dépendent que de l'entrée, pas du `target`).
# - Le baseline `combo_0000` apparaît lui aussi ligne par ligne, avec `gain = 0`.

# %%
import re
from pathlib import Path

import pandas as pd

# === CONFIGURATION ===

# Racine contenant tous les dossiers de runs (un par combo).
# Adaptez ce chemin à votre arborescence WSL, ex:
# BENCHMARK_ROOT = Path("/mnt/c/Users/vous/.../results/benchmark/blob_nn_4x10-1")
BENCHMARK_ROOT = Path("../results/benchmark/blob_nn_4x10-1")

# Nom du dossier de run, ex:
#   2026_07_08_15h28_19s_test__combo_0000__baseline__all_one_variable
#   2026_07_09_01h54_43s_test__combo_0001__product_0__l0_u0_k1_j0__composed
#   2026_07_14_14h56_49s_your_run_title__combo_0232__product_231__l2_u9_k3_j0__composed
RUN_DIR_RE = re.compile(r"combo_(\d+)__(.+)$")
PRODUCT_IDX_RE = re.compile(r"l(\d+)_u(\d+)_k(\d+)_j(\d+)")

# Un combo est gardé seulement s'il a au moins ce nombre de lignes utilisables ;
# au-delà, on tronque aux MAX_RUNS premières lignes ; en dessous, le combo est écarté.
MIN_RUNS = 0
MAX_RUNS = float("inf")

# Clé utilisée pour apparier chaque ligne d'un combo à la ligne correspondante du
# baseline (combo_0000), afin de calculer le gain.
RESULTS_MERGE_KEYS = ["data_index", "target"]

# Clé utilisée pour apparier les bornes LB/UB de stable_actives_study.csv
# (les bornes ne dépendent que de l'entrée, pas du target).
STABLE_MERGE_KEY = "data_index"

# %%
def parse_run_dir(dirname: str) -> dict:
    """Extrait combo_id, stratégie, et les indices (l,u,k,j) si présents."""
    m = RUN_DIR_RE.search(dirname)
    if not m:
        return None

    combo_id = int(m.group(1))
    rest = m.group(2)  # ex: "product_0__l0_u0_k1_j0__composed" ou "baseline__all_one_variable"

    idx_match = PRODUCT_IDX_RE.search(rest)
    if idx_match:
        l, u, k, j = map(int, idx_match.groups())
        strategy = rest.rsplit("__", 1)[-1]  # dernier segment = nom de la stratégie
    else:
        l = u = k = j = None
        strategy = "none" if combo_id == 0 else rest

    return {
        "combo": f"combo_{combo_id:04d}",
        "combo_id": combo_id,
        "strategy": strategy,
        "l": l, "u_idx": u, "k": k, "j_idx": j,
    }


def find_run_dirs(root: Path) -> list[dict]:
    """Retourne la liste des runs trouvés avec leurs métadonnées et chemins de fichiers."""
    if not root.exists():
        raise FileNotFoundError(f"Dossier introuvable: {root.resolve()}")

    runs = []
    for d in sorted(root.glob("*__combo_*")):
        if not d.is_dir():
            continue
        meta = parse_run_dir(d.name)
        if meta is None:
            print(f"[!] Nom de dossier non reconnu, ignoré: {d.name}")
            continue

        results_csv = d / "results.csv"
        stable_csv = d / "stable_actives_study.csv"

        if not results_csv.exists():
            print(f"[!] Pas de results.csv dans {d.name}")
            continue
        if not stable_csv.exists():
            print(f"[!] Pas de stable_actives_study.csv dans {d.name}")

        meta["results_csv"] = results_csv
        meta["stable_csv"] = stable_csv if stable_csv.exists() else None
        meta["dirname"] = d.name
        runs.append(meta)

    # Plusieurs dossiers peuvent partager le même combo_id (reruns à des timestamps
    # différents, parfois des tests rapides avec peu de lignes). On ne peut pas se
    # fier au timestamp le plus récent : un rerun ultérieur peut être un test partiel.
    # On garde donc, pour chaque combo_id, le dossier dont le results.csv a le PLUS
    # de lignes (le run le plus complet).
    groups = {}
    for r in runs:
        groups.setdefault(r["combo_id"], []).append(r)

    deduped = []
    for cid, candidates in groups.items():
        if len(candidates) == 1:
            deduped.append(candidates[0])
            continue

        scored = []
        for c in candidates:
            try:
                n = len(pd.read_csv(c["results_csv"]))
            except Exception as e:
                n = -1
            scored.append((n, c))
        scored.sort(key=lambda x: x[0], reverse=True)

        best_n, best = scored[0]
        print(f"[!] combo_{cid:04d}: {len(candidates)} dossier(s) trouvé(s), on garde celui avec le plus de lignes ({best_n}) -> {best['dirname']}")
        for n, c in scored[1:]:
            print(f"      (ignoré: {n} ligne(s), {c['dirname']})")
        deduped.append(best)

    return sorted(deduped, key=lambda r: r["combo_id"])


runs = find_run_dirs(BENCHMARK_ROOT)
print(f"{len(runs)} run(s) trouvé(s):")
for r in runs:
    print(f"  {r['combo']} ({r['strategy']}) l={r['l']} u={r['u_idx']} k={r['k']} j={r['j_idx']}")
# Out:
# [!] Pas de results.csv dans 2026_07_10_13h31_53s_test__combo_0000__baseline__all_one_variable
# [!] Pas de results.csv dans your_run_title__combo_0163__product_162__l2_u1_k4_j0__composed
# [!] Pas de results.csv dans your_run_title__combo_0247__product_246__l3_u1_k4_j0__composed
# [!] combo_0000: 3 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_08_17h23_07s_test__combo_0000__baseline__all_one_variable
#       (ignoré: 78 ligne(s), 2026_07_09_10h20_23s_test__combo_0000__baseline__all_one_variable)
#       (ignoré: 4 ligne(s), 2026_07_10_10h25_50s_your_run_title__combo_0000__baseline__all_one_variable)
# [!] combo_0001: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_01h54_43s_test__combo_0001__product_0__l0_u0_k1_j0__composed
#       (ignoré: 78 ligne(s), 2026_07_09_11h27_17s_test__combo_0001__product_0__l0_u0_k1_j0__composed)
# [!] combo_0002: 3 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_05h28_38s_test__combo_0002__product_1__l0_u0_k1_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_09_12h34_13s_test__combo_0002__product_1__l0_u0_k1_j1__composed)
#       (ignoré: 78 ligne(s), 2026_07_11_01h52_19s_your_run_title__combo_0002__product_1__l0_u0_k1_j1__composed)
# [!] combo_0003: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (363) -> 2026_07_09_10h00_54s_test__combo_0003__product_2__l0_u0_k1_j2__composed
#       (ignoré: 78 ligne(s), 2026_07_09_13h40_55s_test__combo_0003__product_2__l0_u0_k1_j2__composed)
# [!] combo_0004: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_14h47_35s_test__combo_0004__product_3__l0_u0_k2_j0__composed
#       (ignoré: 78 ligne(s), 2026_07_11_11h56_08s_your_run_title__combo_0004__product_3__l0_u0_k2_j0__composed)
# [!] combo_0006: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_17h01_00s_test__combo_0006__product_5__l0_u0_k2_j2__composed
#       (ignoré: 78 ligne(s), 2026_07_12_13h41_20s_your_run_title__combo_0006__product_5__l0_u0_k2_j2__composed)
# [!] combo_0008: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_19h14_54s_test__combo_0008__product_7__l0_u0_k3_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_11_04h06_11s_your_run_title__combo_0008__product_7__l0_u0_k3_j1__composed)
# [!] combo_0011: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_09_22h35_22s_test__combo_0011__product_10__l0_u0_k4_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_17_04h21_01s_your_run_title__combo_0011__product_10__l0_u0_k4_j1__composed)
# [!] combo_0014: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_01h56_39s_test__combo_0014__product_13__l0_u0_k5_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_15_10h49_50s_your_run_title__combo_0014__product_13__l0_u0_k5_j1__composed)
# [!] combo_0017: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_05h17_36s_test__combo_0017__product_16__l0_u1_k1_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_16_12h47_12s_your_run_title__combo_0017__product_16__l0_u1_k1_j1__composed)
# [!] combo_0018: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_06h24_21s_test__combo_0018__product_17__l0_u1_k1_j2__composed
#       (ignoré: 78 ligne(s), 2026_07_16_11h40_27s_your_run_title__combo_0018__product_17__l0_u1_k1_j2__composed)
# [!] combo_0019: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_07h31_14s_test__combo_0019__product_18__l0_u1_k2_j0__composed
#       (ignoré: 78 ligne(s), 2026_07_12_09h13_06s_your_run_title__combo_0019__product_18__l0_u1_k2_j0__composed)
# [!] combo_0020: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_08h38_41s_test__combo_0020__product_19__l0_u1_k2_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_15_23h19_26s_your_run_title__combo_0020__product_19__l0_u1_k2_j1__composed)
# [!] combo_0021: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_09h45_28s_test__combo_0021__product_20__l0_u1_k2_j2__composed
#       (ignoré: 78 ligne(s), 2026_07_11_02h59_23s_your_run_title__combo_0021__product_20__l0_u1_k2_j2__composed)
# [!] combo_0022: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_10h52_20s_test__combo_0022__product_21__l0_u1_k3_j0__composed
#       (ignoré: 78 ligne(s), 2026_07_10_21h23_34s_your_run_title__combo_0022__product_21__l0_u1_k3_j0__composed)
# [!] combo_0023: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_10_11h58_57s_test__combo_0023__product_22__l0_u1_k3_j1__composed
#       (ignoré: 78 ligne(s), 2026_07_14_13h50_37s_your_run_title__combo_0023__product_22__l0_u1_k3_j1__composed)
# [!] combo_0172: 2 dossier(s) trouvé(s), on garde celui avec le plus de lignes (78) -> 2026_07_11_05h13_20s_your_run_title__combo_0172__product_171__l2_u2_k4_j0__composed
#       (ignoré: 1 ligne(s), 2026_07_10_12h12_34s_your_run_title__combo_0172__product_171__l2_u2_k4_j0__composed)
# 158 run(s) trouvé(s):
#   combo_0000 (none) l=None u=None k=None j=None
#   combo_0001 (composed) l=0 u=0 k=1 j=0
#   combo_0002 (composed) l=0 u=0 k=1 j=1
#   combo_0003 (composed) l=0 u=0 k=1 j=2
#   combo_0004 (composed) l=0 u=0 k=2 j=0
#   combo_0005 (composed) l=0 u=0 k=2 j=1
#   combo_0006 (composed) l=0 u=0 k=2 j=2
#   combo_0007 (composed) l=0 u=0 k=3 j=0
#   combo_0008 (composed) l=0 u=0 k=3 j=1
#   combo_0009 (composed) l=0 u=0 k=3 j=2
#   combo_0010 (composed) l=0 u=0 k=4 j=0
#   combo_0011 (composed) l=0 u=0 k=4 j=1
#   combo_0012 (composed) l=0 u=0 k=4 j=2
#   combo_0013 (composed) l=0 u=0 k=5 j=0
#   combo_0014 (composed) l=0 u=0 k=5 j=1
#   combo_0015 (composed) l=0 u=0 k=5 j=2
#   combo_0016 (composed) l=0 u=1 k=1 j=0
#   combo_0017 (composed) l=0 u=1 k=1 j=1
#   combo_0018 (composed) l=0 u=1 k=1 j=2
#   combo_0019 (composed) l=0 u=1 k=2 j=0
#   combo_0020 (composed) l=0 u=1 k=2 j=1
#   combo_0021 (composed) l=0 u=1 k=2 j=2
#   combo_0022 (composed) l=0 u=1 k=3 j=0
#   combo_0023 (composed) l=0 u=1 k=3 j=1
#   combo_0026 (composed) l=0 u=1 k=4 j=1
#   combo_0027 (composed) l=0 u=1 k=4 j=2
#   combo_0029 (composed) l=0 u=1 k=5 j=1
#   combo_0031 (composed) l=1 u=0 k=2 j=0
#   combo_0033 (composed) l=1 u=0 k=2 j=2
#   combo_0036 (composed) l=1 u=0 k=3 j=2
#   combo_0037 (composed) l=1 u=0 k=4 j=0
#   combo_0039 (composed) l=1 u=0 k=4 j=2
#   combo_0040 (composed) l=1 u=0 k=5 j=0
#   combo_0043 (composed) l=1 u=1 k=2 j=0
#   combo_0044 (composed) l=1 u=1 k=2 j=1
#   combo_0046 (composed) l=1 u=1 k=3 j=0
#   combo_0047 (composed) l=1 u=1 k=3 j=1
#   combo_0048 (composed) l=1 u=1 k=3 j=2
#   combo_0049 (composed) l=1 u=1 k=4 j=0
#   combo_0050 (composed) l=1 u=1 k=4 j=1
#   combo_0051 (composed) l=1 u=1 k=4 j=2
#   combo_0055 (composed) l=1 u=2 k=2 j=0
#   combo_0066 (composed) l=1 u=2 k=5 j=2
#   combo_0068 (composed) l=1 u=3 k=2 j=1
#   combo_0069 (composed) l=1 u=3 k=2 j=2
#   combo_0071 (composed) l=1 u=3 k=3 j=1
#   combo_0072 (composed) l=1 u=3 k=3 j=2
#   combo_0074 (composed) l=1 u=3 k=4 j=1
#   combo_0079 (composed) l=1 u=4 k=2 j=0
#   combo_0080 (composed) l=1 u=4 k=2 j=1
#   combo_0087 (composed) l=1 u=4 k=4 j=2
#   combo_0092 (composed) l=1 u=5 k=2 j=1
#   combo_0093 (composed) l=1 u=5 k=2 j=2
#   combo_0096 (composed) l=1 u=5 k=3 j=2
#   combo_0099 (composed) l=1 u=5 k=4 j=2
#   combo_0109 (composed) l=1 u=6 k=4 j=0
#   combo_0110 (composed) l=1 u=6 k=4 j=1
#   combo_0115 (composed) l=1 u=7 k=2 j=0
#   combo_0118 (composed) l=1 u=7 k=3 j=0
#   combo_0123 (composed) l=1 u=7 k=4 j=2
#   combo_0125 (composed) l=1 u=7 k=5 j=1
#   combo_0127 (composed) l=1 u=8 k=2 j=0
#   combo_0128 (composed) l=1 u=8 k=2 j=1
#   combo_0134 (composed) l=1 u=8 k=4 j=1
#   combo_0138 (composed) l=1 u=8 k=5 j=2
#   combo_0139 (composed) l=1 u=9 k=2 j=0
#   combo_0140 (composed) l=1 u=9 k=2 j=1
#   combo_0141 (composed) l=1 u=9 k=2 j=2
#   combo_0146 (composed) l=1 u=9 k=4 j=1
#   combo_0149 (composed) l=1 u=9 k=5 j=1
#   combo_0150 (composed) l=1 u=9 k=5 j=2
#   combo_0152 (composed) l=2 u=0 k=3 j=1
#   combo_0154 (composed) l=2 u=0 k=4 j=0
#   combo_0156 (composed) l=2 u=0 k=4 j=2
#   combo_0159 (composed) l=2 u=0 k=5 j=2
#   combo_0160 (composed) l=2 u=1 k=3 j=0
#   combo_0164 (composed) l=2 u=1 k=4 j=1
#   combo_0165 (composed) l=2 u=1 k=4 j=2
#   combo_0167 (composed) l=2 u=1 k=5 j=1
#   combo_0168 (composed) l=2 u=1 k=5 j=2
#   combo_0171 (composed) l=2 u=2 k=3 j=2
#   combo_0172 (composed) l=2 u=2 k=4 j=0
#   combo_0174 (composed) l=2 u=2 k=4 j=2
#   combo_0175 (composed) l=2 u=2 k=5 j=0
#   combo_0177 (composed) l=2 u=2 k=5 j=2
#   combo_0178 (composed) l=2 u=3 k=3 j=0
#   combo_0179 (composed) l=2 u=3 k=3 j=1
#   combo_0181 (composed) l=2 u=3 k=4 j=0
#   combo_0182 (composed) l=2 u=3 k=4 j=1
#   combo_0183 (composed) l=2 u=3 k=4 j=2
#   combo_0184 (composed) l=2 u=3 k=5 j=0
#   combo_0186 (composed) l=2 u=3 k=5 j=2
#   combo_0188 (composed) l=2 u=4 k=3 j=1
#   combo_0190 (composed) l=2 u=4 k=4 j=0
#   combo_0191 (composed) l=2 u=4 k=4 j=1
#   combo_0193 (composed) l=2 u=4 k=5 j=0
#   combo_0194 (composed) l=2 u=4 k=5 j=1
#   combo_0195 (composed) l=2 u=4 k=5 j=2
#   combo_0198 (composed) l=2 u=5 k=3 j=2
#   combo_0199 (composed) l=2 u=5 k=4 j=0
#   combo_0201 (composed) l=2 u=5 k=4 j=2
#   combo_0202 (composed) l=2 u=5 k=5 j=0
#   combo_0204 (composed) l=2 u=5 k=5 j=2
#   combo_0206 (composed) l=2 u=6 k=3 j=1
#   combo_0207 (composed) l=2 u=6 k=3 j=2
#   combo_0209 (composed) l=2 u=6 k=4 j=1
#   combo_0210 (composed) l=2 u=6 k=4 j=2
#   combo_0211 (composed) l=2 u=6 k=5 j=0
#   combo_0212 (composed) l=2 u=6 k=5 j=1
#   combo_0215 (composed) l=2 u=7 k=3 j=1
#   combo_0222 (composed) l=2 u=7 k=5 j=2
#   combo_0223 (composed) l=2 u=8 k=3 j=0
#   combo_0224 (composed) l=2 u=8 k=3 j=1
#   combo_0226 (composed) l=2 u=8 k=4 j=0
#   combo_0228 (composed) l=2 u=8 k=4 j=2
#   combo_0229 (composed) l=2 u=8 k=5 j=0
#   combo_0232 (composed) l=2 u=9 k=3 j=0
#   combo_0233 (composed) l=2 u=9 k=3 j=1
#   combo_0235 (composed) l=2 u=9 k=4 j=0
#   combo_0237 (composed) l=2 u=9 k=4 j=2
#   combo_0240 (composed) l=2 u=9 k=5 j=2
#   combo_0242 (composed) l=3 u=0 k=4 j=1
#   combo_0244 (composed) l=3 u=0 k=5 j=0
#   combo_0245 (composed) l=3 u=0 k=5 j=1
#   combo_0249 (composed) l=3 u=1 k=4 j=2
#   combo_0251 (composed) l=3 u=1 k=5 j=1
#   combo_0252 (composed) l=3 u=1 k=5 j=2
#   combo_0253 (composed) l=3 u=2 k=4 j=0
#   combo_0254 (composed) l=3 u=2 k=4 j=1
#   combo_0259 (composed) l=3 u=3 k=4 j=0
#   combo_0262 (composed) l=3 u=3 k=5 j=0
#   combo_0265 (composed) l=3 u=4 k=4 j=0
#   combo_0267 (composed) l=3 u=4 k=4 j=2
#   combo_0272 (composed) l=3 u=5 k=4 j=1
#   combo_0274 (composed) l=3 u=5 k=5 j=0
#   combo_0275 (composed) l=3 u=5 k=5 j=1
#   combo_0277 (composed) l=3 u=6 k=4 j=0
#   combo_0280 (composed) l=3 u=6 k=5 j=0
#   combo_0282 (composed) l=3 u=6 k=5 j=2
#   combo_0284 (composed) l=3 u=7 k=4 j=1
#   combo_0285 (composed) l=3 u=7 k=4 j=2
#   combo_0288 (composed) l=3 u=7 k=5 j=2
#   combo_0292 (composed) l=3 u=8 k=5 j=0
#   combo_0293 (composed) l=3 u=8 k=5 j=1
#   combo_0294 (composed) l=3 u=8 k=5 j=2
#   combo_0295 (composed) l=3 u=9 k=4 j=0
#   combo_0300 (composed) l=3 u=9 k=5 j=2
#   combo_0301 (composed) l=4 u=0 k=5 j=0
#   combo_0302 (composed) l=4 u=0 k=5 j=1
#   combo_0303 (composed) l=4 u=0 k=5 j=2
#   combo_0313 (composed) l=4 u=4 k=5 j=0
#   combo_0318 (composed) l=4 u=5 k=5 j=2
#   combo_0319 (composed) l=4 u=6 k=5 j=0
#   combo_0321 (composed) l=4 u=6 k=5 j=2
#   combo_0323 (composed) l=4 u=7 k=5 j=1
#   combo_0324 (composed) l=4 u=7 k=5 j=2
#   combo_0329 (composed) l=4 u=9 k=5 j=1
#   combo_0330 (composed) l=4 u=9 k=5 j=2

# %%
def load_limited_csv(csv_path: Path, min_rows: int = MIN_RUNS, max_rows: int = MAX_RUNS) -> pd.DataFrame | None:
    """Charge un CSV, le tronque à max_rows lignes, ou renvoie None s'il en a moins que min_rows."""
    df = pd.read_csv(csv_path)
    n_original = len(df)
    if n_original < min_rows:
        return None
    if n_original > max_rows:
        df = df.iloc[:max_rows].reset_index(drop=True)
    assert len(df) <= max_rows, (
        f"BUG: {csv_path} a {len(df)} lignes après troncature (attendu <= {max_rows})"
    )
    return df

# %%
# === Baseline (combo_0000) ===
baseline_run = next((r for r in runs if r["combo_id"] == 0), None)
if baseline_run is None:
    raise RuntimeError("Aucun combo_0000 (baseline) trouvé — impossible de calculer le gain.")

baseline_results_df = load_limited_csv(baseline_run["results_csv"])
if baseline_results_df is None:
    raise RuntimeError(
        f"combo_0000 a moins de {MIN_RUNS} lignes utilisables — impossible de calculer un gain fiable."
    )

missing_keys = [k for k in RESULTS_MERGE_KEYS if k not in baseline_results_df.columns]
if missing_keys:
    raise RuntimeError(f"Colonnes de jointure manquantes dans results.csv du baseline: {missing_keys}")

print(f"Baseline: {baseline_run['combo']} ({baseline_run['strategy']}) — {len(baseline_results_df)} lignes")
# Out:
# Baseline: combo_0000 (none) — 78 lignes

# %%
def per_point_table(r: dict, baseline_results_df: pd.DataFrame) -> pd.DataFrame | None:
    """Construit une ligne par point de données pour un combo donné, avec gain et bornes LB/UB."""
    results_df = load_limited_csv(r["results_csv"])
    if results_df is None:
        return None

    # IMPORTANT: `data_index` est un compteur global qui continue de s'incrémenter
    # d'un combo à l'autre (ex: baseline = 0..76, combo_0001 = 921..999...), donc sa
    # valeur brute ne peut PAS servir à identifier "la même image" entre deux combos.
    # On apparie donc par POSITION relative : on trie chaque fichier par data_index
    # croissant (ordre de test), puis on compare le 1er point du combo au 1er point
    # du baseline, le 2e au 2e, etc.
    results_sorted = results_df.sort_values("data_index").reset_index(drop=True)
    results_sorted["point_rank"] = results_sorted.index

    baseline_sorted = baseline_results_df.sort_values("data_index").reset_index(drop=True)
    baseline_sorted["point_rank"] = baseline_sorted.index

    df = results_sorted[["data_index", "target", "optimal_value", "point_rank"]].copy()
    df["certified"] = results_sorted["optimal_value"] > 0

    # Gain point par point vs baseline (jointure sur la position, pas sur data_index)
    merged = df.merge(
        baseline_sorted[["point_rank", "optimal_value"]],
        on="point_rank",
        suffixes=("", "_baseline"),
        how="left",
    )
    if merged["optimal_value_baseline"].isna().any():
        n_missing = merged["optimal_value_baseline"].isna().sum()
        print(f"[!] {r['combo']}: {n_missing} ligne(s) sans correspondance dans le baseline (longueurs différentes ?)")
    merged["gain"] = merged["optimal_value"] - merged["optimal_value_baseline"]
    merged = merged.drop(columns=["optimal_value_baseline", "point_rank"])

    # Bornes LB/UB par data_index, depuis stable_actives_study.csv (même dossier,
    # donc même numérotation data_index — pas besoin de matching par position ici)
    stable_df = load_limited_csv(r["stable_csv"]) if r["stable_csv"] is not None else None
    lb1_col = f"LB_Layer_{r['l']}_Neuron_{r['u_idx']}" if r["l"] is not None else None
    ub1_col = f"UB_Layer_{r['l']}_Neuron_{r['u_idx']}" if r["l"] is not None else None
    lb2_col = f"LB_Layer_{r['k']}_Neuron_{r['j_idx']}" if r["k"] is not None else None
    ub2_col = f"UB_Layer_{r['k']}_Neuron_{r['j_idx']}" if r["k"] is not None else None

    for col_name, source_col in [
        ("LB_neuron1", lb1_col), ("UB_neuron1", ub1_col),
        ("LB_neuron2", lb2_col), ("UB_neuron2", ub2_col),
    ]:
        if stable_df is None or source_col is None or source_col not in stable_df.columns:
            merged[col_name] = float("nan")
        else:
            bounds = stable_df[[STABLE_MERGE_KEY, source_col]].rename(columns={source_col: col_name})
            merged = merged.merge(bounds, on=STABLE_MERGE_KEY, how="left")

    merged.insert(0, "combo", r["combo"])
    merged.insert(1, "strategy", r["strategy"])
    merged.insert(2, "l", r["l"])
    merged.insert(3, "u_idx", r["u_idx"])
    merged.insert(4, "k", r["k"])
    merged.insert(5, "j_idx", r["j_idx"])

    return merged

# %%
tables = []
skipped = []

for r in runs:
    t = per_point_table(r, baseline_results_df)
    if t is None:
        skipped.append(r["combo"])
        continue
    tables.append(t)

if skipped:
    print(f"{len(skipped)} combo(s) écarté(s) (moins de {MIN_RUNS} runs): {skipped}")

detail_df = pd.concat(tables, ignore_index=True)

# Vérification explicite : aucun combo ne doit dépasser MAX_RUNS lignes.
counts = detail_df.groupby("combo").size()
bad = counts[counts > MAX_RUNS]
if not bad.empty:
    raise AssertionError(f"Combos dépassant MAX_RUNS lignes après troncature: {bad.to_dict()}")

detail_df = detail_df[
    [
        "combo", "strategy", "l", "u_idx", "k", "j_idx",
        "data_index", "target", "certified", "optimal_value", "gain",
        "LB_neuron1", "UB_neuron1", "LB_neuron2", "UB_neuron2",
    ]
]
detail_df
# Out:
# [!] combo_0000: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0001: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0002: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0003: 286 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0004: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0005: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0006: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0007: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0008: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0009: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0010: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0011: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0012: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0013: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0014: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0015: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0016: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0017: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0018: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0019: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0020: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0021: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0022: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0023: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0026: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0027: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0029: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0031: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0033: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0036: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0037: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0039: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0040: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0043: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0044: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0046: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0047: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0048: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0049: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0050: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0051: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0055: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0066: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0068: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0069: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0071: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0072: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0074: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0079: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0080: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0087: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0092: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0093: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0096: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0099: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0109: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0110: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0115: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0118: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0123: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0125: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0127: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0128: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0134: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0138: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0139: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0140: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0141: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0146: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0149: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0150: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0152: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0154: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0156: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0159: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0160: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0164: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0165: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0167: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0168: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0171: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0172: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0174: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0175: 312 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0177: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0178: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0179: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0181: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0182: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0183: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0184: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0186: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0188: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0190: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0191: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0193: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0194: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0195: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0198: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0199: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0201: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0202: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0204: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0206: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0207: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0209: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0210: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0211: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0212: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0215: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0222: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0223: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0224: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0226: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0228: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0229: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0232: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0233: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0235: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0237: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0240: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0242: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0244: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0245: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0249: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0251: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0252: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0253: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0254: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0259: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0262: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0265: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0267: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0272: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0274: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0275: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0277: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0280: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0282: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0284: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0285: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0288: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0292: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0293: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0294: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0295: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0300: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0301: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0302: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0303: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0313: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0318: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0319: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0321: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0323: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0324: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0329: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
# [!] combo_0330: 1 ligne(s) sans correspondance dans le baseline (longueurs différentes ?)
#             combo  strategy     l u_idx     k j_idx  data_index  target  \
# 0      combo_0000      none  None  None  None  None         921     NaN
# 1      combo_0000      none  None  None  None  None         922     NaN
# 2      combo_0000      none  None  None  None  None         923     NaN
# 3      combo_0000      none  None  None  None  None         924     NaN
# 4      combo_0000      none  None  None  None  None         925     NaN
# ...           ...       ...   ...   ...   ...   ...         ...     ...
# 12841  combo_0330  composed     4     9     5     2         995     NaN
# 12842  combo_0330  composed     4     9     5     2         996     NaN
# 12843  combo_0330  composed     4     9     5     2         997     NaN
# 12844  combo_0330  composed     4     9     5     2         998     NaN
# 12845  combo_0330  composed     4     9     5     2         999     NaN
#
#        certified  optimal_value          gain  LB_neuron1  UB_neuron1  \
# 0          False            NaN           NaN         NaN         NaN
# 1          False      -3.313258  0.000000e+00         NaN         NaN
# 2           True       0.051073  0.000000e+00         NaN         NaN
# 3           True       3.160486  0.000000e+00         NaN         NaN
# 4          False      -4.975583  0.000000e+00         NaN         NaN
# ...          ...            ...           ...         ...         ...
# 12841      False     -11.537115  2.774279e-07   -1.330692    0.199566
# 12842       True       1.105619  2.666593e-02   -2.688242   -1.124644
# 12843       True       3.335567  6.267938e-02   -3.066478   -0.740262
# 12844       True       2.335883  1.588252e-03   -2.868703   -0.776741
# 12845      False      -9.296944  3.135556e-07   -1.004692    0.424983
#
#        LB_neuron2  UB_neuron2
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 12841   -7.090365   70.517860
# 12842   -7.004410   49.300579
# 12843  -12.573580   -8.179303
# 12844  -11.508393   -1.407166
# 12845   -5.326673   84.223526
#
# [12846 rows x 15 columns]

# %% [markdown]
# ## Export (CSV, une ligne par point de données)

# %%
OUTPUT_CSV = "combo_detail_by_datapoint.csv"
detail_df.to_csv(OUTPUT_CSV, index=False)
print(f"Tableau exporté vers {OUTPUT_CSV} ({len(detail_df)} lignes)")
# Out:
# Tableau exporté vers combo_detail_by_datapoint.csv (12846 lignes)

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\run blob with relu_quadratic_random false\results.csv")

# %%
df1.mean(numeric_only=True)
# Out:
# data_index                       461.435453
# label                              0.990366
# label_predicted                    0.990366
# target                             0.859345
# epsilon                            0.500000
# status                             1.000000
# MATRIX_BY_LAYERS                   1.000000
# LAST_LAYER                         0.000000
# USE_STABLE_ACTIVES                 1.000000
# USE_STABLE_INACTIVES               0.000000
# Nb_stable_inactives               16.547206
# Nb_stable_actives                  0.000000
# Nb_constraints                   197.582531
# Nb_variables                            NaN
# RLT                                1.000000
# triangularization                  1.000000
# McCormick_beta_z                   0.000000
# beta_logits_comparaison            0.000000
# beta_logits_comparaison_big_M      0.000000
# sum_beta_logits_equal_logit        0.000000
# RLT_prop                           0.100000
# ...

# %%
percentage_optimal = (df1['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 54.66%

# %%
df2=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\relu_quadratic_random_true\results.csv")

# %%
percentage_optimal2 = (df2['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal2:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 52.52%

# %%
df2.mean(numeric_only=True)['time']
# Out:
# np.float64(10.036395043777905)

# %%
dfsans=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\sanscuts\results.csv")

# %%
percentage_optimal_sans = (dfsans['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_sans:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 25.00%

# %%
dfsans.mean(numeric_only=True)['time']
# Out:
# np.float64(10.11515986919403)

# %%
dfrlt=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\rlt\results.csv")

# %%
percentage_optimal_rlt = (dfrlt['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_rlt:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 27.27%

# %%
dfsans.mean(numeric_only=True)['time']
# Out:
# np.float64(10.11515986919403)

# %%
dftri=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\triangularization\results.csv")

# %%
percentage_optimal_tri = (dftri['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 25.00%

# %%
dftri.mean(numeric_only=True)['time']
# Out:
# np.float64(10.077923216138567)

# %%
dfmc=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\McCormick_beta_z\results.csv")

# %%
percentage_optimal_mc = (dfmc['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_mc:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 30.00%

# %%
dfmc.mean(numeric_only=True)['time']
# Out:
# np.float64(10.067274141311646)

# %%
dfbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\beta_logits_comparaison\results.csv")

# %%
percentage_optimal_beta = (dfbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_beta:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 33.33%

# %%
dfbeta.mean(numeric_only=True)['time']
# Out:
# np.float64(10.090003534599587)

# %%
dfbetaM=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\beta_logits_comparaison_big_M\results.csv")

# %%
percentage_optimal_betaM = (dfbetaM['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_betaM:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 32.14%

# %%
dfbetaM.mean(numeric_only=True)['time']
# Out:
# np.float64(10.084629433495659)

# %%
dfsumbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\sum_beta_logits_equal_logit\results.csv")

# %%
percentage_optimal_sumbeta = (dfsumbeta['optimal_value'][:20] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_sumbeta:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 25.00%

# %%
print(sorted({"rlt": percentage_optimal_rlt, "sans": percentage_optimal_sans, "tri": percentage_optimal_tri, "mc": percentage_optimal_mc, "beta": percentage_optimal_beta, "betaM": percentage_optimal_betaM, "sumbeta": percentage_optimal_sumbeta}.items()))
# Out:
# [('beta', np.float64(33.33333333333333)), ('betaM', np.float64(32.142857142857146)), ('mc', np.float64(30.0)), ('rlt', np.float64(27.27272727272727)), ('sans', np.float64(25.0)), ('sumbeta', np.float64(25.0)), ('tri', np.float64(37.142857142857146))]

# %% [markdown]
# il est claire que les plus pertinant sont tri,sumbeta,beta,betaM
# on test avec des cobinision de ces heristique

# %%
dftrisumbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\triangularization_sum_beta_logits_equal_logit\results.csv")

# %%
percentage_optimal_triangularization_sumbeta = (dftrisumbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimale_value > 0: {percentage_optimal_triangularization_sumbeta:.2f}%")
# Out:
# Percentage of data where optimale_value > 0: 27.27%

# %%
dftribetaM.mean(numeric_only=True)['time']
# Out:
# np.float64(10.084629433495659)

# %%
dftribeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\triangularization_beta_logits_comparaison\results.csv")

# %%
percentage_optimal_tribeta = (dftribeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_tribeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 26.09%

# %%
dfsumbetabeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\sum_beta_logits_equal_logit_beta_logits_comparaison\results.csv")

# %%
percentage_optimal_sumbetabeta = (dfsumbetabeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_sumbetabeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 25.00%

# %% [markdown]
# il est clair que les percentage ne sont pas en evoultion avec la combinition des contraintes les plus pertinant
# ce qui nous ramener a devoir tester tous les combinision

# %%
dfrlttri=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\rlt_triangularization\results.csv")

# %%
percentage_optimal_rlttri = (dfrlttri['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_rlttri:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 41.18%

# %% [markdown]
# pour un reson ou un autre on voit que triangulaire avec rlt a donner une meilleur resultat suite a cttte piste c'est claire que ca serait interassatnt d'utiliser la contrainte rlt

# %%
dfrltsumbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\RLT_sum_beta_logits_equal_logit\results.csv")

# %%
percentage_optimal_rltsumbeta = (dfrltsumbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_rltsumbeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 35.56%

# %%
dfrltbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\RLT_beta_logits_comparaison\results.csv")

# %%
percentage_optimal_rltbeta = (dfrltbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_rltbeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 35.48%

# %%
dfrltbeta.mean(numeric_only=True)['time']
# Out:
# np.float64(10.09138757951798)

# %%
dfrltMsumbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\RLT_McCormick_beta_z_sum_beta_logits_equal_logit\results.csv")

# %%
percentage_optimal_rltMsumbeta = (dfrltMsumbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_rltMsumbeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 39.36%

# %%
dfrltbeta.mean(numeric_only=True)['time']
# Out:
# np.float64(10.09138757951798)

# %%
dfrlttrisumbeta=pd.read_csv(r"C:\Users\ahmed\fst\FastSDPCertification\results\benchmark\blob_nn_4x10-0.5\RLT_TRI_SUM\results.csv")

# %%
percentage_optimal_rlttrisumbeta = (dfrlttrisumbeta['optimal_value'] > 0).mean() * 100
print(f"Percentage of data where optimal_value > 0: {percentage_optimal_rlttrisumbeta:.2f}%")
# Out:
# Percentage of data where optimal_value > 0: 38.10%
